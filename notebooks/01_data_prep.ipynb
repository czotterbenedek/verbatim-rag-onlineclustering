# %%
from datasets import load_dataset

# %%
acl = load_dataset(
    "KRLabsOrg/acl-verbatim-spans",
    "canonical"
)

print(acl)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# canonical/train-00000-of-00001.parquet:   0%|          | 0.00/31.1M [00:00<?, ?B/s]
# canonical/validation-00000-of-00001.parq(…):   0%|          | 0.00/3.38M [00:00<?, ?B/s]
# canonical/test-00000-of-00001.parquet:   0%|          | 0.00/145k [00:00<?, ?B/s]
# ...
# Generating test split:   0%|          | 0/100 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'paper_id', 'chunk_index', 'chunk', 'label', 'answerable', 'spans', 'source', 'retrieval_rank', 'gold_paper', 'gold_chunk', 'predicted_texts', 'latency_s', 'err'],
#         num_rows: 20916
#     })
#     validation: Dataset({
#         features: ['question', 'paper_id', 'chunk_index', 'chunk', 'label', 'answerable', 'spans', 'source', 'retrieval_rank', 'gold_paper', 'gold_chunk', 'predicted_texts', 'latency_s', 'err'],
#         num_rows: 2319
#     })
#     test: Dataset({
# ...
